# %%
import numpy as np
import pandas as pd

# %%
text = "d_pet_pictures.txt"
file = open(text,"r")
List = file.read().split("\n")
file.close()

# %%
list2=List.copy()

# %%
def In(List):
    length = int(List.pop(0))

    Picture =  {}

    Pic_V = []
    Pic_H = []

    for i in range(length):
        Pic = List.pop(0).split(" ",2)
        Picture[i] = [Pic[0],int(Pic[1]),[Pic[2]]]
    
    for i in range(length):
        if Picture[i][0] == "H":
            Pic_H.append([i,Picture[i][1:]])
        elif Picture[i][0] == "V":
            Pic_V.append([i,Picture[i][1:]])
        
    return (length,Picture,Pic_V,Pic_H)

# %%
length,Picture,Pic_V,Pic_H=In(List)

# %%
Pic_V
# Out:
# [[1, [15, ['tz2 t56 t42 t47 th5 tx4 tp6 t52 tm2 tw3 tw6 t85 t82 tn6 t87']]],
#  [3, [13, ['tq1 tv3 tx1 tn6 t86 tc1 tb7 t72 t52 tw3 tm5 tr5 th4']]],
#  [5, [15, ['t02 tr2 t52 tp6 th5 t37 ts2 tl5 tn3 t44 th4 tv2 tq1 tn6 td']]],
#  [6, [9, ['tq6 t8 tv4 tz t22 t05 tn6 th4 t87']]],
#  [7, [11, ['tx tp2 tq6 tc4 t37 tr5 tb7 tl5 t8 t52 th4']]],
#  [8, [5, ['tl tw3 tp t6 t53']]],
#  [10, [12, ['tb5 t05 tv t02 t12 tm2 t87 t8 tf1 tp6 tx2 tm5']]],
#  [12, [13, ['tm t85 tw5 th5 tb t86 t05 tc5 tq2 tn3 tr5 t87 tc4']]],
#  [13, [9, ['t87 t05 tw5 tb th6 t82 tz2 t01 t62']]],
#  [14, [12, ['tx1 t6 tx4 t52 t31 t86 tw3 th6 tr5 td2 tq2 t44']]],
#  [15, [9, ['t6 t52 t05 tw5 tz6 tw3 t47 tc1 t34']]],
#  [16, [9, ['t42 tp2 tw3 t47 tn6 tf1 td1 t52 t85']]],
#  [17, [4, ['th5 tm2 tw5 t86']]],
#  [18, [8, ['t82 tp2 tr5 tp tm2 t86 tw6 tl5']]],
#  [24, [14, ['tw3 tm2 tt6 tz6 t6 tp2 t01 t82 tz4 tc4 th6 tc5 t95 tz2']]],
#  [25, [9, ['tq1 tb7 th5 tq2 t47 th6 td6 td4 t93']]],
# ...

# %%
list2

list_1,list_2=Pic_H,Pic_V
list_g=[Pic_H,Pic_V]
print(list_g)
# Out:
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)

# %%
a=["a","d","d"]
b=["b","g","r"]

c= [a,b]
print(c)
# Out:
# [['a', 'd', 'd'], ['b', 'g', 'r']]

# %%
list2
def checkMin(S1,S2):
    e_1=0
    n_1=0
    n_2=0
    E_list=[]
    for i in range(len(S1)):
        for j in range(len(S2)):
            if S1[i]==S2[j]:
                e_1+=1
    n_1=len(S1)-e_1
    n_2=len(S2)-e_1
    return (min(e_1,n_1,n_2))

# %%
S1=["a","b","c","f","t","g"]
S2=["e","a","d"]
S3=["b","a","y"]
#checkMin(S1,S2)
checkMin(S1,S3)
# Out:
# 1

# %%
def Smax(S1,S2,S3):
    
    if checkMin(S1,S2)>=checkMin(S1,S3):
        return S2
    else:
        return S3

# %%
S1=["a","b","c","f","t","g"]
S2=["e","a","d"]
S3=["b","a","y"]
Smax(S1,S2,S3)
# Out:
# ['e', 'a', 'd']

# %%
def tri()
